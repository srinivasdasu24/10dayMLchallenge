# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
cereal_data=pd.read_csv("cereal.csv")

# %%
cereal_data.describe()
# Out:
#          calories    protein        fat      sodium      fiber      carbo  \
# count   77.000000  77.000000  77.000000   77.000000  77.000000  77.000000
# mean   106.883117   2.545455   1.012987  159.675325   2.151948  14.597403
# std     19.484119   1.094790   1.006473   83.832295   2.383364   4.278956
# min     50.000000   1.000000   0.000000    0.000000   0.000000  -1.000000
# 25%    100.000000   2.000000   0.000000  130.000000   1.000000  12.000000
# 50%    110.000000   3.000000   1.000000  180.000000   2.000000  14.000000
# 75%    110.000000   3.000000   2.000000  210.000000   3.000000  17.000000
# max    160.000000   6.000000   5.000000  320.000000  14.000000  23.000000
#
#           sugars      potass    vitamins      shelf     weight       cups  \
# count  77.000000   77.000000   77.000000  77.000000  77.000000  77.000000
# mean    6.922078   96.077922   28.246753   2.207792   1.029610   0.821039
# std     4.444885   71.286813   22.342523   0.832524   0.150477   0.232716
# ...

# %%
cereal_data.infer_objects
# Out:
# <bound method NDFrame.infer_objects of                          name mfr type  calories  protein  fat  sodium  fiber  \
# 0                   100% Bran   N    C        70        4    1     130   10.0
# 1           100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                    All-Bran   K    C        70        4    1     260    9.0
# 3   All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4              Almond Delight   R    C       110        2    2     200    1.0
# ..                        ...  ..  ...       ...      ...  ...     ...    ...
# 72                    Triples   G    C       110        2    1     250    0.0
# 73                       Trix   G    C       110        1    1     140    0.0
# 74                 Wheat Chex   R    C       100        3    1     230    3.0
# 75                   Wheaties   G    C       100        3    1     200    3.0
# ...

# %%
cereal_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77 entries, 0 to 76
# Data columns (total 16 columns):
# name        77 non-null object
# mfr         77 non-null object
# type        77 non-null object
# calories    77 non-null int64
# protein     77 non-null int64
# fat         77 non-null int64
# sodium      77 non-null int64
# fiber       77 non-null float64
# carbo       77 non-null float64
# sugars      77 non-null int64
# potass      77 non-null int64
# vitamins    77 non-null int64
# shelf       77 non-null int64
# weight      77 non-null float64
# cups        77 non-null float64
# rating      77 non-null float64
# dtypes: float64(5), int64(8), object(3)
# memory usage: 9.8+ KB

# %%
cereal_data.isnull
# Out:
# <bound method DataFrame.isnull of                          name mfr type  calories  protein  fat  sodium  fiber  \
# 0                   100% Bran   N    C        70        4    1     130   10.0
# 1           100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                    All-Bran   K    C        70        4    1     260    9.0
# 3   All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4              Almond Delight   R    C       110        2    2     200    1.0
# ..                        ...  ..  ...       ...      ...  ...     ...    ...
# 72                    Triples   G    C       110        2    1     250    0.0
# 73                       Trix   G    C       110        1    1     140    0.0
# 74                 Wheat Chex   R    C       100        3    1     230    3.0
# 75                   Wheaties   G    C       100        3    1     200    3.0
# 76        Wheaties Honey Gold   G    C       110        2    1     200    1.0
#
# ...

# %%
cereal_data.head()
# Out:
#                         name mfr type  calories  protein  fat  sodium  fiber  \
# 0                  100% Bran   N    C        70        4    1     130   10.0
# 1          100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                   All-Bran   K    C        70        4    1     260    9.0
# 3  All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4             Almond Delight   R    C       110        2    2     200    1.0
#
#    carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 0    5.0       6     280        25      3     1.0  0.33  68.402973
# 1    8.0       8     135         0      3     1.0  1.00  33.983679
# 2    7.0       5     320        25      3     1.0  0.33  59.425505
# 3    8.0       0     330        25      3     1.0  0.50  93.704912
# 4   14.0       8      -1        25      3     1.0  0.75  34.384843

# %%
sns.set_palette("GnBu_d")
sns.set_style('whitegrid')

# %%
sns.jointplot(x='sodium',y='calories',data=cereal_data)

# %%
sns.pairplot(cereal_data)

# %%
sns.jointplot(x='rating',y='fiber',kind='hex',data=cereal_data)

# %%
sns.countplot(x="mfr",data=cereal_data, palette='OrRd_r')

# %%
sns.distplot(cereal_data["rating"])

# %%
sns.heatmap(cereal_data.corr())

# %%
plt.figure(figsize=(12, 7))
sns.boxplot(x='mfr',y='rating',data=cereal_data,palette='rainbow_r')

# %%
import statsmodels.api as sm
sugars = cereal_data['sugars'].values
rating = cereal_data['rating'].values



plt.scatter(sugars, rating, alpha = 0.4)
plt.xlabel("Sugars")
plt.ylabel("Nutritional Rating")
plt.title("Cereal Rating by Sugar Content")
plt.plot(sugars,rating ,alpha=0.6)

# %%
plt.figure(figsize=(20,20))
sns.barplot(x=cereal_data["rating"].sort_values(ascending=False).reset_index(drop=True),y=cereal_data["name"])
plt.xlabel("Product Name")
plt.ylabel("Rating")
plt.title("product rating")
plt.show()

# %%
sns.lmplot(x='rating',y='calories',data=cereal_data)

# %%
cereal_data.dropna(inplace=True)

# %%
cereal_data['rating'].plot.hist(bins=20,figsize=(10,5))
plt.xlabel("Rating")
plt.ylabel("numbers")
plt.show()

# %%
cereal_data.drop(['name','mfr','type'],axis=1,inplace=True)

# %%
cereal_data.head()
# Out:
#    calories  protein  fat  sodium  fiber  carbo  sugars  potass  vitamins  \
# 0        70        4    1     130   10.0    5.0       6     280        25
# 1       120        3    5      15    2.0    8.0       8     135         0
# 2        70        4    1     260    9.0    7.0       5     320        25
# 3        50        4    0     140   14.0    8.0       0     330        25
# 4       110        2    2     200    1.0   14.0       8      -1        25
#
#    shelf  weight  cups     rating
# 0      3     1.0  0.33  68.402973
# 1      3     1.0  1.00  33.983679
# 2      3     1.0  0.33  59.425505
# 3      3     1.0  0.50  93.704912
# 4      3     1.0  0.75  34.384843

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(cereal_data.drop('rating',axis=1), 
                                                    cereal_data['rating'], test_size=0.30, 
                                                    random_state=101)

# %%
from sklearn.linear_model import LinearRegression
lm = LinearRegression()
lm.fit(X_train,Y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
print('Coefficients: \n', lm.coef_)
# Out:
# Coefficients:
#  [-2.22724169e-01  3.27317386e+00 -1.69140797e+00 -5.44927027e-02
#   3.44347983e+00  1.09245097e+00 -7.24895098e-01 -3.39933516e-02
#  -5.12119674e-02 -4.26678659e-08 -7.74261187e-07  1.61133676e-07]

# %%
predictions = lm.predict( X_test)

# %%
plt.scatter(Y_test,predictions)
plt.xlabel('Y Test')
plt.ylabel('Predicted Y')
# Out:
# Text(0, 0.5, 'Predicted Y')

# %%
score=metrics.r2_score(Y_test, predictions)
print(score)
# Out:
# 0.9999999999999992

# %%
from sklearn import metrics

print('MAE:', metrics.mean_absolute_error(Y_test, predictions))
print('MSE:', metrics.mean_squared_error(Y_test, predictions))
print('RMSE:', np.sqrt(metrics.mean_squared_error(Y_test, predictions)))
# Out:
# MAE: 3.362415375759061e-07
# MSE: 1.6181611919271883e-13
# RMSE: 4.0226374332360457e-07

# %%
sns.distplot((Y_test-predictions),bins=50);

# %%
coeffecients = pd.DataFrame(lm.coef_,X.columns[:-1])
coeffecients.columns = ['Coeffecient']
coeffecients
# Out:
#            Coeffecient
# calories -2.227242e-01
# protein   3.273174e+00
# fat      -1.691408e+00
# sodium   -5.449270e-02
# fiber     3.443480e+00
# carbo     1.092451e+00
# sugars   -7.248951e-01
# potass   -3.399335e-02
# vitamins -5.121197e-02
# shelf    -4.266787e-08
# weight   -7.742612e-07
# cups      1.611337e-07
